# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга"

# %% [markdown]
# ## Обязательная часть

# %% [markdown]
# Вам необходимо написать функцию, которая будет основана на **поиске** по сайту [habr.com](https://habr.com/ru/search/).
# Функция в качестве параметра должна принимать **список** запросов для поиска (например, `['python', 'анализ данных']`) и на основе материалов, попавших в результаты поиска по **каждому** запросу, возвращать датафрейм вида:
#
# ```
# <дата> - <заголовок> - <ссылка на материал>
# ```
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %% [markdown]
# #### Инициализация

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
URL_domain = 'https://habr.com'
URL_search = 'https://habr.com/ru/search/'

def searching_habr(URL_domain, URL_search, query):
    '''
    Поиск по сайту habr.com
        результаты поиска по каждому запросу, возвращается датафрейм вида:
        <дата> - <заголовок> - <ссылка на материал>
    
    Предполагается работа только с одной (первой) страницей 
    результатов поисковой выдачи для каждого запроса. 
    
    Материалы не дублируются, 
        если они попадали в результаты поиска для нескольких запросов из списка.
    
    Параметры:
        URL_domain - доменное имя сайта (на сайте ссылке хранятся как локальные, к ним надо достроит доменное имя)
        URL_search - поисковая строка для GET
        query - список запросов для поиска (например, ['python', 'анализ данных']) 
    
    '''
    
#   Шаблон результирующего DF
    df_searched = pd.DataFrame(columns=['дата','заголовок','ссылка на материал'])
    
#     Поиск по каждому поисковому запросу
    for qry_el in query:
        params = {'q' : qry_el}
        res = requests.get(URL_search, params = params)
        soup = BeautifulSoup(res.text)

        searched = soup.find_all('article')
    
#         Запись в DF
#         Если запись уже существует, то дополнения не производится

        for el in searched:
#     есть неожиданный блок с другим классом и структурой (текст, ссылка и т.п.)
#     class_=tm-megapost-snippet
#     Его игнорируем, но в целом можно и его распаспарсить
#     из-за этого блока конструкция ниже дает СБОЙ после применения find (элементы разные по структуре)
#     Ошибка:
#         'NoneType' object has no attribute 'text'

            try:
                title = el.find('h2', 'tm-title tm-title_h2').text
                date = el.find('span', 'tm-article-datetime-published').text

                # ссылки в href локальные, надо добавлять домен вручную
                link = el.find('a', 'tm-title__link').get('href')
                link_full = requests.compat.urljoin(URL_domain, link)
            except:
                # Игнорируем те результаты, у которых структура класса другая
                pass
            
#             Если материал уже ранее найден, его не дополняем в DF
            if not df_searched['ссылка на материал'].isin([link_full]).any():
                df_searched.loc[len(df_searched)] = date, title, link_full
                
    return df_searched

# Проверка работы 
query_list=['python', 'анализ данных']
# query_list=['анализ данных'] #конкретно тут был сбой (статья в другом формате)
# query_list=['python']
searching_habr(URL_domain, URL_search, query_list)
# Out:
#                      дата                                          заголовок  \
# 0    3  мар  2020 в 13:22  В начале этого года Python сместил Java и стал...
# 1       12  апр   в 12:57         Ядро планеты Python. Интерактивный учебник
# 2       10  июл   в 11:00  Опенсорс-библиотеки для Python: 40+ вариантов,...
# 3   26  сен  2022 в 13:54         Java из Python (Kivy) и обратно на Android
# 4        7  июл   в 15:27     Как сделать из Python-скрипта исполняемый файл
# 5   31  окт  2019 в 10:02  Создатель Python Гвидо ван Россум ушел из Drop...
# 6        7  июл   в 22:50  Линейная алгебра самым простым языком с добавл...
# 7       21  мар   в 16:35  Moscow Python Meetup x YADRO: встречаемся 23 м...
# 8       27  июн   в 08:01  Messaging для чайников. Утилизируем все возмож...
# 9        6  мар   в 15:53  Как стать Python-разработчиком: сессия вопросо...
# 10      28  мар   в 11:03  «Python-разработка для начинающих» — бесплатны...
# 11            1 час назад  Начало работы с AWS. Создание IAM пользователя...
# 12      24  мар   в 14:03  А теперь нечто совсем иное! Митап «Типичный Py...
# 13      14  июл   в 10:40  Что нового в Python за июнь — обсуждаем в прям...
# 14       6  апр   в 10:08  Что нового в Python за март — обсуждаем в прям...
# 15       5  мая   в 09:03  Что нового в Python за апрель — обсуждаем в пр...
# 16      23  мар   в 11:52              Углубляемся в Python на Evrone meetup
# 17  20  янв  2022 в 18:37  Курс «Python для инженеров». Старт 3 потока 31...
# 18  21  апр  2020 в 18:35  Вышел Python 2.7.18, последний релиз ветки Pyt...
# 19  13  дек  2021 в 09:00  Жаждущим автоматизации: открытый урок «ChatOps...
# 20  25  июл  2012 в 13:29                      Пять лет Школе анализа данных
# 21  25  июл  2017 в 13:47                10 лет Школе анализа данных Яндекса
# 22  10  авг  2022 в 15:52  Как за две недели проверить гипотезы применимо...
# 23  14  янв  2021 в 10:00  Что такое бессерверный SQL? И как использовать...
# 24  21  янв  2019 в 11:21  Как мы строим систему обработки, хранения и ан...
# 25       8  июн   в 13:18  В VK Cloud стал доступен инструмент поиска и а...
# 26  14  мая  2020 в 13:39  Ubic создаст платформу для анализа данных о мо...
# 27  27  июн  2017 в 13:51  Использование Python и Excel для обработки и а...
# 28  30  июн  2014 в 23:06  Обзор наиболее интересных материалов по анализ...
# 29  23  ноя  2014 в 16:49  Обзор наиболее интересных материалов по анализ...
# 30  18  июн  2014 в 15:19  Обзор наиболее интересных материалов по анализ...
# 31  13  окт  2014 в 14:00  Обзор наиболее интересных материалов по анализ...
# 32  16  апр  2020 в 07:10  Microsoft анонсировала запуск «Планетарного ко...
# 33  13  ноя  2021 в 19:15  Владимир Путин выступил с Германом Грефом на к...
# 34  10  дек  2021 в 13:15  Интенсив для повышения квалификации: как испол...
# 35  18  янв  2015 в 18:02  Обзор наиболее интересных материалов по анализ...
# 36  28  июл  2014 в 13:10  Обзор наиболее интересных материалов по анализ...
# 37  11  авг  2014 в 10:47  Обзор наиболее интересных материалов по анализ...
# 38  14  сен  2014 в 19:54  Обзор наиболее интересных материалов по анализ...
#
#                                    ссылка на материал
# 0   https://habr.com/ru/companies/itsumma/news/490...
# 1                https://habr.com/ru/articles/728568/
# 2   https://habr.com/ru/companies/first/articles/7...
# 3                https://habr.com/ru/articles/683536/
# 4   https://habr.com/ru/companies/southbridge/arti...
# 5                    https://habr.com/ru/news/473926/
# 6                https://habr.com/ru/articles/746686/
# 7    https://habr.com/ru/companies/yadro/news/723806/
# 8                https://habr.com/ru/articles/743192/
# 9   https://habr.com/ru/companies/yandex_praktikum...
# 10  https://habr.com/ru/companies/netologyru/news/...
# 11               https://habr.com/ru/articles/748276/
# 12  https://habr.com/ru/companies/selectel/news/72...
# 13                   https://habr.com/ru/news/747966/
# 14                   https://habr.com/ru/news/727298/
# 15                   https://habr.com/ru/news/733472/
# 16  https://habr.com/ru/companies/evrone/news/724246/
# 17  https://habr.com/ru/companies/southbridge/news...
# 18                   https://habr.com/ru/news/498364/
# 19  https://habr.com/ru/companies/southbridge/news...
# 20  https://habr.com/ru/companies/yandex/articles/...
# 21  https://habr.com/ru/companies/yandex/articles/...
# 22  https://habr.com/ru/companies/factory5/article...
# 23  https://habr.com/ru/companies/microsoft/articl...
# 24  https://habr.com/ru/companies/sibur_official/a...
# 25                   https://habr.com/ru/news/740666/
# 26                   https://habr.com/ru/news/501944/
# 27  https://habr.com/ru/companies/otus/articles/33...
# 28               https://habr.com/ru/articles/228187/
# 29               https://habr.com/ru/articles/243967/
# 30               https://habr.com/ru/articles/226641/
# 31               https://habr.com/ru/articles/240139/
# 32                   https://habr.com/ru/news/497474/
# 33                   https://habr.com/ru/news/588991/
# 34  https://habr.com/ru/companies/netologyru/news/...
# 35               https://habr.com/ru/articles/248165/
# 36               https://habr.com/ru/articles/231323/
# 37               https://habr.com/ru/articles/232879/
# 38               https://habr.com/ru/articles/236757/

# %% [markdown]
# ## Дополнительная часть (необязательная)

# %% [markdown]
# Функция из обязательной части задания должна быть расширена следующим образом:
# - кроме списка ключевых слов для поиска необходимо объявить параметр с количеством страниц поисковой выдачи. Т.е. при передаче в функцию аргумента `4` необходимо получить материалы с первых 4 страниц результатов;
# - в датафрейме должны быть столбцы с полным текстом найденных материалов и количеством лайков:
# ```
# <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>
# ```

# %%
URL_domain = 'https://habr.com'
URL_search = 'https://habr.com/ru/search/'

def searching_habr_extended(URL_domain, URL_search, query, page_qty):
    '''
    Поиск по сайту habr.com
        результаты поиска по каждому запросу, возвращается датафрейм вида:
        <дата> - <заголовок> - <ссылка на материал> - <текст материала> - <количество лайков>
        
    Расширение функции searching_habr():
        - Добавлен  параметр с количеством страниц поисковой выдачи. 
        При передаче в функцию аргумента `4` будут получены материалы с первых 4 страниц результатов
        - добавлены столбцы с полным текстом найденных материалов и количеством лайков
    
    Материалы не дублируются, 
        если они попадали в результаты поиска для нескольких запросов из списка.
    
    Параметры:
        URL_domain - доменное имя сайта (на сайте ссылке хранятся как локальные, к ним надо достроит доменное имя)
        URL_search - поисковая строка для GET
        query - список запросов для поиска (например, ['python', 'анализ данных'])
        page_qty - количество страниц поисковой выдачи    
    '''
    
#   Шаблон результирующего DF
    # количество лайков - такое не найдено на habr. По смыслу подходит "Всего голосов" (внизу статьи)
    df_searched = pd.DataFrame(columns=[
        'дата',
        'заголовок',
        'ссылка на материал', 
        'текст материала', 
        'количество лайков', 
        'поисковый запрос',
        'найдено на странице №'
    ])
    

#     Поиск по каждому поисковому запросу
    for page in range(1, page_qty + 1):

        # счетчик страниц - формируем адрес страницы
        # шаблон на habr: https://habr.com/ru/search/page3/<всякие параметры>
        URL_search_page = URL_search + 'page' + str(page) + '/'
        
        for qry_el in query:
            params = {'q' : qry_el}
            res = requests.get(URL_search_page, params = params)
            
            # проверка существования страницы
            if res.status_code != 200:
                print(f'Страница № {page} не найдена')
                return df_searched
            
            soup = BeautifulSoup(res.text)
            searched = soup.find_all('article')
            
            for el in searched:
                try:
                    title = el.find('h2', 'tm-title tm-title_h2').text
                    date = el.find('span', 'tm-article-datetime-published').text

                    # ссылки в href локальные, надо добавлять домен вручную
                    link = el.find('a', 'tm-title__link').get('href')
                    link_full = requests.compat.urljoin(URL_domain, link)

                    # с лайками есть пара варинтов (отражается либо только добавленные, 
                    # либо текст со статистикой, сколько +, сколько -.)
                    # Оставил вариант +-, как более информативный
                    votes = el.find('div', 
                                    'tm-votes-meter tm-data-icons__item').text
                    
#                     Можно и так, но смысл этой цифры - загадка
#                     votes = el.find('span', 
#                        'tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating').text

#                     Достаем полный текст статьи 

                    article_req = requests.get(link_full)
                    article_soup = BeautifulSoup(article_req.text)
#                     time.sleep(0.3)
                    article_req_txt = article_soup.find('div', id = 'post-content-body').text.strip()

                except:
                    # Игнорируем те результаты, у которых структура класса другая
                    pass

            
#              Запись в DF
#              Если материал уже ранее найден, его не дополняем в DF
                if not df_searched['ссылка на материал'].isin([link_full]).any():
                    df_searched.loc[len(df_searched)] = date, title, link_full, article_req_txt, votes, qry_el, page
                
    return df_searched

# Проверка работы 
query_list=['python', 'анализ данных']
# query_list=['python']
# query_list=['asdgere']
searching_habr_extended(URL_domain, URL_search, query_list, 4)
# Out:
#                       дата                                          заголовок  \
# 0     3  мар  2020 в 13:22  В начале этого года Python сместил Java и стал...
# 1        12  апр   в 12:57         Ядро планеты Python. Интерактивный учебник
# 2        10  июл   в 11:00  Опенсорс-библиотеки для Python: 40+ вариантов,...
# 3    26  сен  2022 в 13:54         Java из Python (Kivy) и обратно на Android
# 4         7  июл   в 15:27     Как сделать из Python-скрипта исполняемый файл
# ..                     ...                                                ...
# 153   8  сен  2022 в 14:10  Проблемы качества промышленных данных (временн...
# 154  22  июн  2022 в 12:41  Как мы составили Словарь больших данных для те...
# 155   8  апр  2013 в 12:52  Открытые репозитории кода по открытым данным и...
# 156  24  июн  2016 в 23:12  Достучаться до госорганов или что делать, если...
# 157   3  авг  2015 в 11:36          Что такое Мастер-Данные и зачем они нужны
#
#                                     ссылка на материал  \
# 0    https://habr.com/ru/companies/itsumma/news/490...
# 1                 https://habr.com/ru/articles/728568/
# 2    https://habr.com/ru/companies/first/articles/7...
# 3                 https://habr.com/ru/articles/683536/
# 4    https://habr.com/ru/companies/southbridge/arti...
# ..                                                 ...
# 153  https://habr.com/ru/companies/rosatom/articles...
# 154  https://habr.com/ru/companies/itsumma/articles...
# 155               https://habr.com/ru/articles/175855/
# 156  https://habr.com/ru/companies/infoculture/arti...
# 157  https://habr.com/ru/companies/navicon/articles...
#
#                                        текст материала  \
# 0    Согласно отчету RedMonk за январь 2020 года, P...
# 1    Добрый день! Меня зовут Михаил Емельянов, неда...
# 2    «Удовольствие от программирования на Python до...
# 3    Продолжение статьи C/C++ из Python (ctypes) на...
# 4    Вы изучаете данные и хотите поделиться своим к...
# ..                                                 ...
# 153  Привет, Хабр! На связи Юрий Кацер, эксперт по ...
# 154  Я Павел Свиридонов, гуманитарий, который вмест...
# 155  Для всех кто работает с открытыми данными, дел...
# 156  источник картинки: southriverrestoration.com/w...
# 157  Введение\n\r\n(клик по картинке ведёт внутрь п...
#
#                    количество лайков поисковый запрос  найдено на странице №
# 0    Всего голосов 31: ↑31 и ↓0  +31           python                      1
# 1    Всего голосов 66: ↑66 и ↓0  +66           python                      1
# 2    Всего голосов 11: ↑11 и ↓0  +11           python                      1
# 3       Всего голосов 4: ↑4 и ↓0  +4           python                      1
# 4    Всего голосов 28: ↑18 и ↓10  +8           python                      1
# ..                               ...              ...                    ...
# 153     Всего голосов 6: ↑4 и ↓2  +2    анализ данных                      4
# 154  Всего голосов 20: ↑18 и ↓2  +16    анализ данных                      4
# 155  Всего голосов 31: ↑29 и ↓2  +27    анализ данных                      4
# 156  Всего голосов 20: ↑17 и ↓3  +14    анализ данных                      4
# 157     Всего голосов 8: ↑7 и ↓1  +6    анализ данных                      4
#
# [158 rows x 7 columns]

# %% [markdown]
# # Черновики

# %%
URL_search = 'https://habr.com/ru/search/'

URL_search = URL_search + 'page' + str(1) + '/'
URL_search
# Out:
# 'https://habr.com/ru/search/page1/'

# %%
params = {'q' : ['python']}
res = requests.get(URL_search, params = params)
res.status_code
soup = BeautifulSoup(res.text)
soup
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22lang%22:%7B%22ssr%22:%22ru%22%7D%7D" lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1.0,viewport-fit=cover,maximum-scale=1,user-scalable=0" name="viewport"/>
# <meta content="unsafe-url" name="referrer"/>
# <title>Результаты поиска по запросу «python» / Хабр</title>
# <style>
#     /* cyrillic-ext */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveSxf6TF0.woff2) format('woff2');
#       unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
#     }
#
#     /* cyrillic */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveQhf6TF0.woff2) format('woff2');
#       unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
#     }
#
#     /* latin-ext */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveSBf6TF0.woff2) format('woff2');
#       unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;
#     }
#
#     /* latin */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveRhf6.woff2) format('woff2');
#       unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#     }
#
#     /* non-breaking hyphen */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/l/font?kit=KFOlCnqEu92Fr1MmEU9vBh0_IsHAlmrO6g&skey=ee881451c540fdec&v=v29) format('woff2');
#       unicode-range: U+02011;
#     }
#   </style>
# <link as="style" href="https://assets.habr.com/habr-web/css/chunk-vendors.0da14ebf.css" rel="preload"/><link as="script" href="https://assets.habr.com/habr-web/js/chunk-vendors.905d3568.js" rel="preload"/><link as="style" href="https://assets.habr.com/habr-web/css/app.a75c8116.css" rel="preload"/><link as="script" href="https://assets.habr.com/habr-web/js/app.6ad4da81.js" rel="preload"/><link as="style" href="https://assets.habr.com/habr-web/css/search.6ebb9bea.css" rel="preload"/><link as="script" href="https://assets.habr.com/habr-web/js/search.3d288031.js" rel="preload"/><link as="script" href="https://assets.habr.com/habr-web/js/7298.c8f1d73c.js" rel="preload"/>
# <link href="https://assets.habr.com/habr-web/css/chunk-vendors.0da14ebf.css" rel="stylesheet"/><link href="https://assets.habr.com/habr-web/css/app.a75c8116.css" rel="stylesheet"/><link href="https://assets.habr.com/habr-web/css/search.6ebb9bea.css" rel="stylesheet"/>
# <script>window.i18nFetch = new Promise((res, rej) => {
#           const xhr = new XMLHttpRequest();
#           xhr.open('GET', '/js/i18n/ru-compiled.444a78a1e541270f4cf3c3ca27a92873.json');
#           xhr.responseType = 'json';
#           xhr.onload = function(e) {
#             if (this.status === 200) {
#               res({ru: xhr.response});
#             } else {
#               rej(e);
#             }
#           };
#           xhr.send();
#         });</script>
# <style>.grecaptcha-badge{visibility: hidden;}</style>
# <meta content="2.132.1" name="habr-version"/>
# <meta content="/img/habr_ru.png" data-vmid="image:itemprop" data-vue-meta="ssr" itemprop="image"/><meta content="/img/habr_ru.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/><meta content="1200" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/><meta content="630" data-vmid="og:image:height" data-vue-meta="ssr" property="og:image:height"/><meta content="/img/habr_ru.png" data-vmid="aiturec:image" data-vue-meta="ssr" property="aiturec:image"/><meta content="/img/habr_ru.png" data-vmid="twitter:image" data-vue-meta="ssr" name="twitter:image"/><meta content="/img/habr_ru.png?format=vk" data-vmid="vk:image" data-vue-meta="ssr" property="vk:image"/><meta content="444736788986613" data-vue-meta="ssr" property="fb:app_id"/><meta content="472597926099084" data-vue-meta="ssr" property="fb:pages"/><meta content="summary_large_image" data-vue-meta="ssr" name="twitter:card"/><meta content="@habr_com" data-vue-meta="ssr" name="twitter:site"/><meta content="ru_RU" data-vmid="og:locale" data-vue-meta="ssr" property="og:locale"/><meta content="website" data-vmid="og:type" data-vue-meta="ssr" property="og:type"/><meta content="Хабр" data-vmid="og:site_name" data-vue-meta="ssr" property="og:site_name"/><meta content="Хабр" data-vmid="og:title" data-vue-meta="ssr" property="og:title"/><meta content="https://habr.com/ru/search/" data-vmid="og:url" data-vue-meta="ssr" property="og:url"/>
# <link data-vmid="image:href" data-vue-meta="ssr" href="/img/habr_ru.png" rel="image_src"/><link data-vmid="canonical" data-vue-meta="ssr" href="https://habr.com/ru/search/" rel="canonical"/><link data-vue-meta="ssr" href="https://habr.com/ru/rss/search/?q=python++++++++&amp;order_by=undefined++++++++&amp;target_type=undefined++++++++&amp;hl=ru++++++++&amp;fl=ru&amp;fl=ru" name="rss" rel="alternate" title="" type="application/rss+xml"/>
# <meta content="#303b44" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="#629FBC" name="msapplication-TileColor"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/favicon-16.png" rel="shortcut icon" sizes="16x16" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/favicon-32.png" rel="shortcut icon" sizes="32x32" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-76.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-120.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-152.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-180.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-256.png" rel="apple-touch-icon" sizes="256x256" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1136x640.png" media="screen and (device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2436x1125.png" media="screen and (device-width: 375px) and (device-height: 812px) and (-webkit-device-pixel-ratio: 3) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1792x828.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_828x1792.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1334x750.png" media="screen and (device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1242x2668.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2208x1242.png" media="screen and (device-width: 414px) and (device-height: 736px) and (-webkit-device-pixel-ratio: 3) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1125x2436.png" media="screen and (device-width: 375px) and (device-height: 812px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1242x2208.png" media="screen and (device-width: 414px) and (device-height: 736px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2732x2048.png" media="screen and (device-width: 1024px) and (device-height: 1366px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2688x1242.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 3) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2224x1668.png" media="screen and (device-width: 834px) and (device-height: 1112px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_750x1334.png" media="screen and (device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2048x2732.png" media="screen and (device-width: 1024px) and (device-height: 1366px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2388x1668.png" media="screen and (device-width: 834px) and (device-height: 1194px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1668x2224.png" media="screen and (device-width: 834px) and (device-height: 1112px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_640x1136.png" media="screen and (device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1668x2388.png" media="screen and (device-width: 834px) and (device-height: 1194px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2048x1536.png" media="screen and (device-width: 768px) and (device-height: 1024px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1536x2048.png" media="screen and (device-width: 768px) and (device-height: 1024px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link color="#77a2b6" href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-120.svg" rel="mask-icon"/>
# <link crossorigin="use-credentials" href="/manifest.webmanifest" rel="manifest"/>
# <script async="" crossorigin="anonymous" src="https://unpkg.com/pwacompat"></script>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# </head>
# <body>
# <div data-async-called="true" data-server-rendered="true" id="app"><div class="tm-layout__wrapper"><!-- --> <div></div> <div class="tm-feature tm-feature"><!-- --></div> <header class="tm-header"><div class="tm-page-width"><div class="tm-header__container"><div class="tm-header__burger-nav"><button class="tm-header__button tm-header__button_burger" type="button"><svg class="tm-svg-img tm-header__icon tm-header__icon-burger" height="16" width="16"><title>Меню</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#header-burger"></use></svg></button></div> <span class="tm-header__logo-wrap"><a class="tm-header__logo tm-header__logo_ru" href="/ru/"><svg class="tm-svg-img tm-header__icon" height="16" width="16"><title>Хабр</title> <use xlink:href="/img/habr-logo-ru.svg#logo"></use></svg></a> <span class="tm-header__beta-sign" style="display:none;">β</span></span> <!-- --> <div class="tm-header-user-menu tm-header_user-menu"><a class="tm-header-user-menu__item tm-header-user-menu__search router-link-active" href="/ru/search/"><svg class="tm-svg-img tm-header-user-menu__icon tm-header-user-menu__icon_search" height="24" width="24"><title>Поиск</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#search"></use></svg></a> <!-- --> <!-- --> <!-- --> <div class="tm-header-user-menu__item"><button class="tm-header-user-menu__toggle" data-test-id="menu-toggle-guest"><svg class="tm-svg-img tm-header-user-menu__icon tm-header-user-menu__icon_white" height="24" width="24"><title>Профиль</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#header-user"></use></svg></button> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></div></div></header> <div class="tm-layout"><div class="tm-page-progress-bar"></div> <!-- --> <!-- --> <div class="tm-page-width"></div> <main class="tm-layout__container"><div class="tm-page"><div class="tm-page-width"><!-- --> <div class="tm-page__wrapper"><div class="tm-page__main"><div class="pull-down"><!-- --> <div class="pull-down__header" style="height:0px;"><div class="pull-down__content" style="bottom:10px;"><svg class="tm-svg-img pull-down__icon pull-down__arrow" height="24" width="24"><title>Обновить</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#pull-arrow"></use></svg></div></div> <div class="tm-page__top"><form action="/ru/search/" class="tm-search" method="GET"><div class="tm-input-text-decorated tm-search__input tm-input-text-decorated_has-label-after" name="q" placeholder="Поиск"><!-- --> <input class="tm-input-text-decorated__input" name="q" placeholder="Поиск" value="python"/> <div class="tm-input-text-decorated__label tm-input-text-decorated__label_after"><span class="tm-svg-icon__wrapper tm-search__icon"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Поиск</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#input-search"></use></svg></span></div></div> <!-- --> <input name="target_type" type="hidden" value="posts"/> <input hidden="hidden" type="submit"/></form> <div class="tm-tabs tm-tabs_page-header tm-tabs"><div class="tm-tabs__scroll-area"><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link tm-tabs__tab-link tm-tabs__tab-link_active" data-test-id="tab-link-active" href="/ru/search/?q=python&amp;target_type=posts&amp;order=relevance">
#         Публикации
#         <!-- --> <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link tm-tabs__tab-link" href="/ru/search/?q=python&amp;target_type=hubs&amp;order=relevance">
#         Хабы
#         <!-- --> <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link tm-tabs__tab-link" href="/ru/search/?q=python&amp;target_type=companies&amp;order=relevance">
#         Компании
#         <!-- --> <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link tm-tabs__tab-link" href="/ru/search/?q=python&amp;target_type=users&amp;order=relevance">
#         Пользователи
#         <!-- --> <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link tm-tabs__tab-link" href="/ru/search/?q=python&amp;target_type=comments&amp;order=relevance">
#         Комментарии
#         <!-- --> <!-- --></a></span></div> <!-- --></div> <div class="tm-navigation-dropdown tm-navigation-dropdown"><div class="tm-navigation-dropdown__wrapper"><button class="tm-navigation-dropdown__button tm-navigation-dropdown__button"><div class="tm-navigation-dropdown__button-text">
#         по релевантности
#       </div> <svg class="tm-svg-img icon_dropdown-arrow" height="16" width="16"><title>Открыть список</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#arrow-down"></use></svg></button> </div> <ul class="tm-navigation-dropdown__options"><li class="tm-navigation-dropdown__option"><button class="tm-navigation-dropdown__option-button">
#         по релевантности
#         <!-- --></button></li><li class="tm-navigation-dropdown__option"><button class="tm-navigation-dropdown__option-button">
#         по времени
#         <!-- --></button></li><li class="tm-navigation-dropdown__option"><button class="tm-navigation-dropdown__option-button">
#         по рейтингу
#         <!-- --></button></li></ul></div></div> <div class="tm-sub-page" data-async-called="true"><div class="tm-sub-page__main"><div><div class="tm-articles-list"><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="490834" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/ITSumma/" title="ITSumma"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/b2e/6ed/663/b2e6ed663804346daf634c66b987fe62.png" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/ITSumma/">
#       ITSumma
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2020-03-03T10:22:32.000Z" title="2020-03-03, 13:22">3  мар  2020 в 13:22</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/companies/itsumma/news/490834/"><span>В начале этого года <em class="searched-item">Python</em> сместил Java и стал вторым по популярности языком программирования среди разработчиков</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     2 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">27K</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 31: ↑31 и ↓0</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 31: ↑31 и ↓0">+31</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     21
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/companies/itsumma/news/490834/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       35
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="728568" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/sepulkary/" title="sepulkary"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/a29/1c3/e8a/a291c3e8a64e4969a58c4c537f44bb8f.png" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/sepulkary/">
#       sepulkary
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2023-04-12T09:57:56.000Z" title="2023-04-12, 12:57">12  апр   в 12:57</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/articles/728568/"><span>Ядро планеты <em class="searched-item">Python</em>. Интерактивный учебник</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     67 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">20K</span></span></div> <!-- --> <div class="tm-article-snippet__labels-container"><div class="tm-article-snippet__labels"><div class="tm-article-snippet__label tm-article-snippet__label_variant-tutorial"><span>
#           Туториал
#         </span></div> </div></div> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 66: ↑66 и ↓0</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 66: ↑66 и ↓0">+66</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     360
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/articles/728568/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       25
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="745680" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/UprightMan/" title="UprightMan"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/a2e/041/94e/a2e04194e4996406fb2493d8f2c94a2a.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/UprightMan/">
#       UprightMan
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2023-07-10T08:00:02.000Z" title="2023-07-10, 11:00">10  июл   в 11:00</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/companies/first/articles/745680/"><span>Опенсорс-библиотеки для <em class="searched-item">Python</em>: 40+ вариантов, как упростить жизнь начинающего дата-сайентиста</span></a></h2> <div class="tm-article-snippet__stats"><div class="tm-article-complexity tm-article-complexity_complexity-low"><span class="tm-svg-icon__wrapper tm-article-complexity__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Уровень сложности</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#complexity-low"></use></svg></span> <span class="tm-article-complexity__label">
#     Простой
#   </span></div> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     22 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">3.6K</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 10: ↑10 и ↓0</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 10: ↑10 и ↓0">+10</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     109
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/companies/first/articles/745680/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       0
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="746622" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/SovaSova15/" title="SovaSova15"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/f31/9aa/add/f319aaadd5efb8d5489929edc802f6f4.png" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/SovaSova15/">
#       SovaSova15
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2023-07-07T12:27:16.000Z" title="2023-07-07, 15:27">7  июл   в 15:27</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/companies/southbridge/articles/746622/"><span>Как сделать из <em class="searched-item">Python</em>-скрипта исполняемый файл</span></a></h2> <div class="tm-article-snippet__stats"><div class="tm-article-complexity tm-article-complexity_complexity-low"><span class="tm-svg-icon__wrapper tm-article-complexity__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Уровень сложности</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#complexity-low"></use></svg></span> <span class="tm-article-complexity__label">
#     Простой
#   </span></div> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     3 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">14K</span></span></div> <!-- --> <div class="tm-article-snippet__labels-container"><div class="tm-article-snippet__labels"><div class="tm-article-snippet__label tm-article-snippet__label_variant-tutorial"><span>
#           Туториал
#         </span></div> <div class="tm-article-snippet__label tm-article-snippet__label tm-article-snippet__label_variant-translation"><span>
#           Перевод
#         </span></div></div></div> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 28: ↑18 и ↓10</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 28: ↑18 и ↓10">+8</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     161
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/companies/southbridge/articles/746622/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       27
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="473926" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/maybe_elf/" title="maybe_elf"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/592/11d/4bc/59211d4bcd7f9afdadaef515b2b0706d.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/maybe_elf/">
#       maybe_elf
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2019-10-31T07:02:54.000Z" title="2019-10-31, 10:02">31  окт  2019 в 10:02</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/news/473926/"><span>Создатель <em class="searched-item">Python</em> Гвидо ван Россум ушел из Dropbox на пенсию</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     2 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">13K</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 25: ↑24 и ↓1</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 25: ↑24 и ↓1">+23</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     11
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/news/473926/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       21
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="746686" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/nikotin55/" title="nikotin55"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/b48/18a/753/b4818a7532db45ac29fd3a1798de62aa.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/nikotin55/">
#       nikotin55
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2023-07-07T19:50:27.000Z" title="2023-07-07, 22:50">7  июл   в 22:50</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/articles/746686/"><span>Линейная алгебра самым простым языком с добавлением фишек из <em class="searched-item">Python</em> (часть 1)</span></a></h2> <div class="tm-article-snippet__stats"><div class="tm-article-complexity tm-article-complexity_complexity-low"><span class="tm-svg-icon__wrapper tm-article-complexity__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Уровень сложности</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#complexity-low"></use></svg></span> <span class="tm-article-complexity__label">
#     Простой
#   </span></div> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     3 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">6.6K</span></span></div> <!-- --> <div class="tm-article-snippet__labels-container"><div class="tm-article-snippet__labels"><!-- --> <div class="tm-article-snippet__label tm-article-snippet__label tm-article-snippet__label_variant-sandbox"><a href="/ru/sandbox/">
#           Из песочницы
#         </a></div></div></div> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 19: ↑11 и ↓8</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 19: ↑11 и ↓8">+3</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     67
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/articles/746686/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       9
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="723806" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/yadro_team/" title="yadro_team"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/643/716/787/643716787bd18f3c4b710d7530a12579.png" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/yadro_team/">
#       yadro_team
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2023-03-21T13:35:46.000Z" title="2023-03-21, 16:35">21  мар   в 16:35</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/companies/yadro/news/723806/"><span>Moscow <em class="searched-item">Python</em> Meetup x YADRO: встречаемся 23 марта</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     3 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">1K</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 7: ↑7 и ↓0</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 7: ↑7 и ↓0">+7</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     3
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/companies/yadro/news/723806/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       0
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="743192" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/Propan671/" title="Propan671"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/820/23a/e73/82023ae73f3dcef16422f6612d5f8350.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/Propan671/">
#       Propan671
# ...
#     7
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/articles/748230/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       1
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="747644" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/Propan671/" title="Propan671"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/820/23a/e73/82023ae73f3dcef16422f6612d5f8350.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/Propan671/">
#       Propan671
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2023-07-12T18:07:42.000Z" title="2023-07-12, 21:07">12  июл   в 21:07</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/articles/747644/"><span>RabbitMQ Direct Reply-to. RPC поверх кролика без дополнительных очередей (пример на <em class="searched-item">Python</em>)</span></a></h2> <div class="tm-article-snippet__stats"><div class="tm-article-complexity tm-article-complexity_complexity-medium"><span class="tm-svg-icon__wrapper tm-article-complexity__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Уровень сложности</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#complexity-medium"></use></svg></span> <span class="tm-article-complexity__label">
#     Средний
#   </span></div> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     5 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">2.4K</span></span></div> <!-- --> <div class="tm-article-snippet__labels-container"><div class="tm-article-snippet__labels"><div class="tm-article-snippet__label tm-article-snippet__label_variant-tutorial"><span>
#           Туториал
#         </span></div> </div></div> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 10: ↑10 и ↓0</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 10: ↑10 и ↓0">+10</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     49
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/articles/747644/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       3
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --></div> <!-- --> <div class="tm-pagination"><div class="tm-pagination__navigation-link" data-pagination-prev="" event="" id="pagination-prev-page" rel="prev"><svg class="tm-svg-img tm-pagination__arrow tm-pagination__arrow_prev" height="16" width="16"><title>Назад</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#arrow-back"></use></svg> <span class="tm-pagination__navigation-link-title">
#       Сюда
#     </span></div> <div class="tm-pagination__pages"> <span class="tm-pagination__page tm-pagination__page_current">
#       1
#     </span> <div class="tm-pagination__page-group"><a class="tm-pagination__page" href="/ru/search/page2/?q=python">
#         2
#       </a> <span class="tm-pagination__page tm-pagination__page_skip">
#         ...
#       </span></div><div class="tm-pagination__page-group"><a class="tm-pagination__page" href="/ru/search/page50/?q=python">
#         50
#       </a> <!-- --></div></div> <a class="tm-pagination__navigation-link tm-pagination__navigation-link_active" data-pagination-next="" href="/ru/search/page2/?q=python" id="pagination-next-page" rel="next"><span class="tm-pagination__navigation-link-title">
#       Туда
#     </span> <svg class="tm-svg-img tm-pagination__arrow tm-pagination__arrow_next" height="16" width="16"><title>Назад</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#arrow-back"></use></svg></a></div></div></div> <!-- --></div></div></div> <!-- --></div></div></div></main> <!-- --></div> <!-- --> <div class="tm-footer"><div class="tm-page-width"><div class="tm-footer__container"><div class="tm-footer__title"><a class="tm-svg-icon__wrapper tm-footer__title-link router-link-active" href="/ru/"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Хабр</title> <use xlink:href="/img/habr-logo-ru.svg#logo"></use></svg></a></div> <div class="tm-footer__social"><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://www.facebook.com/habrahabr.ru" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Facebook</title> <use xlink:href="/img/social-icons-sprite.svg#social-logo-facebook"></use></svg></a><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://twitter.com/habr_com" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Twitter</title> <use xlink:href="/img/social-icons-sprite.svg#social-logo-twitter"></use></svg></a><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://vk.com/habr" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>VK</title> <use xlink:href="/img/social-icons-sprite.svg#social-logo-vkontakte"></use></svg></a><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://telegram.me/habr_com" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Telegram</title> <use xlink:href="/img/social-icons-sprite.svg#social-logo-telegram"></use></svg></a><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://www.youtube.com/channel/UCd_sTwKqVrweTt4oAKY5y4w" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Youtube</title> <use xlink:href="/img/social-icons-sprite.svg#social-logo-youtube"></use></svg></a><a class="tm-svg-icon__wrapper tm-social-icons__icon" href="https://zen.yandex.ru/habr" rel="nofollow noopener noreferrer" target="_blank"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Яндекс Дзен</title> <use xlink:href="/img/social-icons-sprite.svg#social-logo-zen"></use></svg></a></div> <div class="v-portal" style="display:none;"></div> <button class="tm-footer__link"><svg class="tm-svg-img tm-footer__icon" height="16" width="16"><title>Язык</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#lang"></use></svg>
#         Настройка языка
#       </button> <a class="tm-footer__link" href="/ru/feedback/">
#         Техническая поддержка
#       </a> <a class="tm-footer__link" href="/berserk-mode-nope">
#         Вернуться на старую версию
#       </a> <div class="tm-footer-copyright"><span class="tm-copyright"><span class="tm-copyright__years">© 2006–2023, </span> <span class="tm-copyright__name"><a class="tm-copyright__link" href="https://company.habr.com/" rel="noopener" target="_blank">Habr</a></span></span></div></div></div></div> <!-- --> <!-- --></div> <div class="vue-portal-target"></div></div>
# <script>window.__INITIAL_STATE__={"adblock":{"hasAcceptableAdsFilter":false,"hasAdblock":false},"articlesList":{"articlesList":{"473926":{"id":"473926","timePublished":"2019-10-31T07:02:54+00:00","isCorporative":false,"lang":"ru","titleHtml":"Создатель \u003Cem class=\"searched-item\"\u003EPython\u003C\u002Fem\u003E Гвидо ван Россум ушел из Dropbox на пенсию","editorVersion":"1.0","postType":"news","postLabels":[],"author":{"id":"2176401","alias":"maybe_elf","fullname":null,"avatarUrl":"\u002F\u002Fhabrastorage.org\u002Fgetpro\u002Fhabr\u002Favatars\u002F592\u002F11d\u002F4bc\u002F59211d4bcd7f9afdadaef515b2b0706d.jpg","speciality":"Информационная служба Хабра"},"statistics":{"commentsCount":21,"favoritesCount":11,"readingCount":13172,"score":23,"votesCount":25,"votesCountPlus":24,"votesCountMinus":1},"hubs":[{"id":"340","alias":"python","type":"collective","title":"Python","titleHtml":"Python","isProfiled":true,"relatedData":null},{"id":"359","alias":"programming","type":"collective","title":"Программирование","titleHtml":"Программирование","isProfiled":true,"relatedData":null},{"id":"22026","alias":"itcompanies","type":"collective","title":"IT-компании","titleHtml":"IT-компании","isProfiled":false,"relatedData":null}],"flows":[{"id":"1","alias":"develop","title":"Разработка","titleHtml":"Разработка"},{"id":"7","alias":"popsci","title":"Научпоп","titleHtml":"Научпоп"}],"relatedData":null,"leadData":{"textHtml":"\u003Cimg src=\"https:\u002F\u002Fhabrastorage.org\u002Fwebt\u002Fal\u002Fq9\u002Fcv\u002Falq9cvqm4qoaz0118e8qccjfxxc.png\" alt=\"image\"\u002F\u003E\u003Cbr\u002F\u003E\r\n\u003Cbr\u002F\u003E\r\nСоздатель языка программирования Python Гвидо ван Россум уходит из Dropbox. Компания \u003Ca href=\"https:\u002F\u002Fblog.dropbox.com\u002Ftopics\u002Fcompany\u002Fthank-you--guido\"\u003Eобъявила об этом решении\u003C\u002Fa\u003E 29 октября.\u003Cbr\u002F\u003E\r\n\u003Cbr\u002F\u003E\r\nНидерландский программист проработал в компании 6,5 лет. Теперь 63-летний Гвидо отправляется на пенсию. \u003Cbr\u002F\u003E\r\n\u003Cbr\u002F\u003E\r\nВ Dropbox заявили, что Россум начал вносить свой вклад в развитие компании фактически с первого дня работы. «Что мне нравится в Python, так это то, что он просто работает. Это так интуитивно и красиво оформлено. Многие из этих атрибутов вдохновили меня и моего соучредителя Араша, когда мы думали о дизайне для Dropbox», — отметил генеральный директор Дрю Хьюстон.\u003Cbr\u002F\u003E\r\n\u003Cbr\u002F\u003E\r\n«Это ощущение горькой радости. Я ухожу из Dropbox, теперь я на пенсии. Я многому научился здесь и буду скучать по работе», — написал сам ван Россум. ","imageUrl":null,"buttonTextHtml":null,"image":null},"status":"published","plannedPublishTime":null,"checked":null,"format":null,"readingTime":2,"complexity":null,"tags":[{"titleHtml":"python"},{"titleHtml":"dropbox"},{"titleHtml":"языки программирования"}]},"490834":{"id":"490834","timePublished":"2020-03-03T10:22:32+00:00","isCorporative":true,"lang":"ru","titleHtml":"В начале этого года \u003Cem class=\"searched-item\"\u003EPython\u003C\u002Fem\u003E сместил Java и стал вторым по популярности языком программирования среди разработчиков","editorVersion":"1.0","postType":"news","postLabels":[],"author":{"id":"1103966","alias":"ITSumma","fullname":"ITSumma","avatarUrl":"\u002F\u002Fhabrastorage.org\u002Fgetpro\u002Fhabr\u002Favatars\u002Fb2e\u002F6ed\u002F663\u002Fb2e6ed663804346daf634c66b987fe62.png","speciality":"Аккаунт компании"},"statistics":{"commentsCount":35,"favoritesCount":21,"readingCount":27392,"score":31,"votesCount":31,"votesCountPlus":31,"votesCountMinus":0},"hubs":[{"id":"12926","alias":"itsumma","type":"corporative","title":"Блог компании ITSumma","titleHtml":"Блог компании ITSumma","isProfiled":false,"relatedData":null},{"id":"340","alias":"python","type":"collective","title":"Python","titleHtml":"Python","isProfiled":true,"relatedData":null},{"id":"359","alias":"programming","type":"collective","title":"Программирование", ...
# <script defer="" src="https://assets.habr.com/habr-web/js/chunk-vendors.905d3568.js"></script><script defer="" src="https://assets.habr.com/habr-web/js/search.3d288031.js"></script><script defer="" src="https://assets.habr.com/habr-web/js/7298.c8f1d73c.js"></script><script defer="" src="https://assets.habr.com/habr-web/js/app.6ad4da81.js"></script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-S28W1WC23F"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#     </script>
# <script type="text/javascript">
#     (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#     m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#     (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#     ym(24049213, "init", {
#       defer:true,
#       trackLinks:true,
#       accurateTrackBounce:true,
#       webvisor:false,
#     });
#   </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/24049213" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <script type="text/javascript">
#       window.addEventListener('load', function () {
#         setTimeout(() => {
#           const img = new Image();
#           img.src = 'https://vk.com/rtrg?p=VK-RTRG-421343-57vKE';
#         }, 0);
#       });
#     </script>
# <script onload="window['zhY4i4nJ9K'] = true" src="/js/ads.js"></script>
# </body>
# </html>

# %%
title = soup.find('h2', 'tm-title tm-title_h2').text
# votes = soup.find('div', 
#                 'tm-votes-meter tm-data-icons__item').text
votes = soup.find('span', 
                'tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating').text
print(title, votes)
# Out:
# В начале этого года Python сместил Java и стал вторым по популярности языком программирования среди разработчиков +31

# %%
page_qty = 4
for page in range(1, page_qty + 1):
    print(page)
# Out:
# 1
# 2
# 3
# 4

# %%
L_domain = 'https://habr.com'
URL_search = 'https://habr.com/ru/search/'

def test_searching_habr(URL_domain, URL_search, query, searched):
    
#   Шаблон результирующего DF
    df_searched = pd.DataFrame(columns=['дата','заголовок','ссылка на материал'])
    
#     Поиск по каждому поисковому запросу
    for qry_el in query:
        params = {'q' : qry_el}
        res = requests.get(URL_search, params = params)
        soup = BeautifulSoup(res.text)
        print(soup)
        searched = soup.find_all('article')

        print(type(soup),  type(searched))
#         print(len(searched))
#         print(searched[0].prettify())
#         for el in searched[0]:
#             print(el.prettify())
#         for tag in searched.find_all('h2'):
#             print("{0}: {1}".format(tag.name, tag.text))
        
        #             title = el.find('h2', 'tm-title tm-title_h2').text
#             print(title)
#         print(soup.div['tm-articles-list'])
#         searched = soup.find_all('div', class_="tm-articles-list")
#         article_item = searched.find_all('article', class_='tm-articles-list__item').text
#         print(searched)
#         print(article_item)
#         Запись в DF
#         Если запись уже существует, то дополнения не производится
#         for el in searched:
#             title = el.find('h2', 'tm-title tm-title_h2').text
#             date = el.find('span', 'tm-article-datetime-published').text
            
#             # ссылки в href локальные, надо добавлять домен вручную
#             link = el.find('a', 'tm-title__link').get('href')
#             link_full = requests.compat.urljoin(URL_domain, link)
            
# #             Если материал уже ранее найден, его не дополняем в DF
#             if not df_searched['ссылка на материал'].isin([link_full]).any():
#                 df_searched.loc[len(df_searched)] = date, title, link_full
                
    return df_searched, searched

# Проверка работы 
# query_list=['python', 'анализ данных']
# query_list=['анализ данных']
query_list=['python']
test_searching_habr(URL_domain, URL_search, query_list, searched)
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22lang%22:%7B%22ssr%22:%22ru%22%7D%7D" lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1.0,viewport-fit=cover,maximum-scale=1,user-scalable=0" name="viewport"/>
# <meta content="unsafe-url" name="referrer"/>
# <title>Результаты поиска по запросу «python» / Хабр</title>
# <style>
#     /* cyrillic-ext */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveSxf6TF0.woff2) format('woff2');
#       unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
#     }
#
#     /* cyrillic */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveQhf6TF0.woff2) format('woff2');
#       unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
#     }
#
#     /* latin-ext */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveSBf6TF0.woff2) format('woff2');
#       unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;
#     }
#
#     /* latin */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveRhf6.woff2) format('woff2');
#       unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
#     }
#
#     /* non-breaking hyphen */
#     @font-face {
#       font-family: 'Fira Sans';
#       font-style: normal;
#       font-weight: 500;
#       font-display: swap;
#       src: url(https://fonts.gstatic.com/l/font?kit=KFOlCnqEu92Fr1MmEU9vBh0_IsHAlmrO6g&skey=ee881451c540fdec&v=v29) format('woff2');
#       unicode-range: U+02011;
#     }
#   </style>
# <link as="style" href="https://assets.habr.com/habr-web/css/chunk-vendors.0da14ebf.css" rel="preload"/><link as="script" href="https://assets.habr.com/habr-web/js/chunk-vendors.905d3568.js" rel="preload"/><link as="style" href="https://assets.habr.com/habr-web/css/app.a75c8116.css" rel="preload"/><link as="script" href="https://assets.habr.com/habr-web/js/app.6ad4da81.js" rel="preload"/><link as="style" href="https://assets.habr.com/habr-web/css/search.6ebb9bea.css" rel="preload"/><link as="script" href="https://assets.habr.com/habr-web/js/search.3d288031.js" rel="preload"/><link as="script" href="https://assets.habr.com/habr-web/js/7298.c8f1d73c.js" rel="preload"/>
# <link href="https://assets.habr.com/habr-web/css/chunk-vendors.0da14ebf.css" rel="stylesheet"/><link href="https://assets.habr.com/habr-web/css/app.a75c8116.css" rel="stylesheet"/><link href="https://assets.habr.com/habr-web/css/search.6ebb9bea.css" rel="stylesheet"/>
# <script>window.i18nFetch = new Promise((res, rej) => {
#           const xhr = new XMLHttpRequest();
#           xhr.open('GET', '/js/i18n/ru-compiled.444a78a1e541270f4cf3c3ca27a92873.json');
#           xhr.responseType = 'json';
#           xhr.onload = function(e) {
#             if (this.status === 200) {
#               res({ru: xhr.response});
#             } else {
#               rej(e);
#             }
#           };
#           xhr.send();
#         });</script>
# <style>.grecaptcha-badge{visibility: hidden;}</style>
# <meta content="2.132.1" name="habr-version"/>
# <meta content="/img/habr_ru.png" data-vmid="image:itemprop" data-vue-meta="ssr" itemprop="image"/><meta content="/img/habr_ru.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/><meta content="1200" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/><meta content="630" data-vmid="og:image:height" data-vue-meta="ssr" property="og:image:height"/><meta content="/img/habr_ru.png" data-vmid="aiturec:image" data-vue-meta="ssr" property="aiturec:image"/><meta content="/img/habr_ru.png" data-vmid="twitter:image" data-vue-meta="ssr" name="twitter:image"/><meta content="/img/habr_ru.png?format=vk" data-vmid="vk:image" data-vue-meta="ssr" property="vk:image"/><meta content="444736788986613" data-vue-meta="ssr" property="fb:app_id"/><meta content="472597926099084" data-vue-meta="ssr" property="fb:pages"/><meta content="summary_large_image" data-vue-meta="ssr" name="twitter:card"/><meta content="@habr_com" data-vue-meta="ssr" name="twitter:site"/><meta content="ru_RU" data-vmid="og:locale" data-vue-meta="ssr" property="og:locale"/><meta content="website" data-vmid="og:type" data-vue-meta="ssr" property="og:type"/><meta content="Хабр" data-vmid="og:site_name" data-vue-meta="ssr" property="og:site_name"/><meta content="Хабр" data-vmid="og:title" data-vue-meta="ssr" property="og:title"/><meta content="https://habr.com/ru/search/" data-vmid="og:url" data-vue-meta="ssr" property="og:url"/>
# <link data-vmid="image:href" data-vue-meta="ssr" href="/img/habr_ru.png" rel="image_src"/><link data-vmid="canonical" data-vue-meta="ssr" href="https://habr.com/ru/search/" rel="canonical"/><link data-vue-meta="ssr" href="https://habr.com/ru/rss/search/?q=python++++++++&amp;order_by=undefined++++++++&amp;target_type=undefined++++++++&amp;hl=ru++++++++&amp;fl=ru&amp;fl=ru" name="rss" rel="alternate" title="" type="application/rss+xml"/>
# <meta content="#303b44" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="#629FBC" name="msapplication-TileColor"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/favicon-16.png" rel="shortcut icon" sizes="16x16" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/favicon-32.png" rel="shortcut icon" sizes="32x32" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-76.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-120.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-152.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-180.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-256.png" rel="apple-touch-icon" sizes="256x256" type="image/png"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1136x640.png" media="screen and (device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2436x1125.png" media="screen and (device-width: 375px) and (device-height: 812px) and (-webkit-device-pixel-ratio: 3) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1792x828.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_828x1792.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1334x750.png" media="screen and (device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1242x2668.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2208x1242.png" media="screen and (device-width: 414px) and (device-height: 736px) and (-webkit-device-pixel-ratio: 3) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1125x2436.png" media="screen and (device-width: 375px) and (device-height: 812px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1242x2208.png" media="screen and (device-width: 414px) and (device-height: 736px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2732x2048.png" media="screen and (device-width: 1024px) and (device-height: 1366px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2688x1242.png" media="screen and (device-width: 414px) and (device-height: 896px) and (-webkit-device-pixel-ratio: 3) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2224x1668.png" media="screen and (device-width: 834px) and (device-height: 1112px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_750x1334.png" media="screen and (device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2048x2732.png" media="screen and (device-width: 1024px) and (device-height: 1366px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2388x1668.png" media="screen and (device-width: 834px) and (device-height: 1194px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1668x2224.png" media="screen and (device-width: 834px) and (device-height: 1112px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_640x1136.png" media="screen and (device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1668x2388.png" media="screen and (device-width: 834px) and (device-height: 1194px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_2048x1536.png" media="screen and (device-width: 768px) and (device-height: 1024px) and (-webkit-device-pixel-ratio: 2) and (orientation: landscape)" rel="apple-touch-startup-image"/>
# <link href="https://assets.habr.com/habr-web/img/splashes/splash_1536x2048.png" media="screen and (device-width: 768px) and (device-height: 1024px) and (-webkit-device-pixel-ratio: 2) and (orientation: portrait)" rel="apple-touch-startup-image"/>
# <link color="#77a2b6" href="https://assets.habr.com/habr-web/img/favicons/apple-touch-icon-120.svg" rel="mask-icon"/>
# <link crossorigin="use-credentials" href="/manifest.webmanifest" rel="manifest"/>
# <script async="" crossorigin="anonymous" src="https://unpkg.com/pwacompat"></script>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# </head>
# <body>
# <div data-async-called="true" data-server-rendered="true" id="app"><div class="tm-layout__wrapper"><!-- --> <div></div> <div class="tm-feature tm-feature"><!-- --></div> <header class="tm-header"><div class="tm-page-width"><div class="tm-header__container"><div class="tm-header__burger-nav"><button class="tm-header__button tm-header__button_burger" type="button"><svg class="tm-svg-img tm-header__icon tm-header__icon-burger" height="16" width="16"><title>Меню</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#header-burger"></use></svg></button></div> <span class="tm-header__logo-wrap"><a class="tm-header__logo tm-header__logo_ru" href="/ru/"><svg class="tm-svg-img tm-header__icon" height="16" width="16"><title>Хабр</title> <use xlink:href="/img/habr-logo-ru.svg#logo"></use></svg></a> <span class="tm-header__beta-sign" style="display:none;">β</span></span> <!-- --> <div class="tm-header-user-menu tm-header_user-menu"><a class="tm-header-user-menu__item tm-header-user-menu__search router-link-active" href="/ru/search/"><svg class="tm-svg-img tm-header-user-menu__icon tm-header-user-menu__icon_search" height="24" width="24"><title>Поиск</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#search"></use></svg></a> <!-- --> <!-- --> <!-- --> <div class="tm-header-user-menu__item"><button class="tm-header-user-menu__toggle" data-test-id="menu-toggle-guest"><svg class="tm-svg-img tm-header-user-menu__icon tm-header-user-menu__icon_white" height="24" width="24"><title>Профиль</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#header-user"></use></svg></button> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></div></div></header> <div class="tm-layout"><div class="tm-page-progress-bar"></div> <!-- --> <!-- --> <div class="tm-page-width"></div> <main class="tm-layout__container"><div class="tm-page"><div class="tm-page-width"><!-- --> <div class="tm-page__wrapper"><div class="tm-page__main"><div class="pull-down"><!-- --> <div class="pull-down__header" style="height:0px;"><div class="pull-down__content" style="bottom:10px;"><svg class="tm-svg-img pull-down__icon pull-down__arrow" height="24" width="24"><title>Обновить</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#pull-arrow"></use></svg></div></div> <div class="tm-page__top"><form action="/ru/search/" class="tm-search" method="GET"><div class="tm-input-text-decorated tm-search__input tm-input-text-decorated_has-label-after" name="q" placeholder="Поиск"><!-- --> <input class="tm-input-text-decorated__input" name="q" placeholder="Поиск" value="python"/> <div class="tm-input-text-decorated__label tm-input-text-decorated__label_after"><span class="tm-svg-icon__wrapper tm-search__icon"><svg class="tm-svg-img tm-svg-icon" height="16" width="16"><title>Поиск</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#input-search"></use></svg></span></div></div> <!-- --> <input name="target_type" type="hidden" value="posts"/> <input hidden="hidden" type="submit"/></form> <div class="tm-tabs tm-tabs_page-header tm-tabs"><div class="tm-tabs__scroll-area"><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link tm-tabs__tab-link tm-tabs__tab-link_active" data-test-id="tab-link-active" href="/ru/search/?q=python&amp;target_type=posts&amp;order=relevance">
#         Публикации
#         <!-- --> <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link tm-tabs__tab-link" href="/ru/search/?q=python&amp;target_type=hubs&amp;order=relevance">
#         Хабы
#         <!-- --> <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link tm-tabs__tab-link" href="/ru/search/?q=python&amp;target_type=companies&amp;order=relevance">
#         Компании
#         <!-- --> <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link tm-tabs__tab-link" href="/ru/search/?q=python&amp;target_type=users&amp;order=relevance">
#         Пользователи
#         <!-- --> <!-- --></a></span><span class="tm-tabs__tab-item"><a class="tm-tabs__tab-link tm-tabs__tab-link" href="/ru/search/?q=python&amp;target_type=comments&amp;order=relevance">
#         Комментарии
#         <!-- --> <!-- --></a></span></div> <!-- --></div> <div class="tm-navigation-dropdown tm-navigation-dropdown"><div class="tm-navigation-dropdown__wrapper"><button class="tm-navigation-dropdown__button tm-navigation-dropdown__button"><div class="tm-navigation-dropdown__button-text">
#         по релевантности
#       </div> <svg class="tm-svg-img icon_dropdown-arrow" height="16" width="16"><title>Открыть список</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#arrow-down"></use></svg></button> </div> <ul class="tm-navigation-dropdown__options"><li class="tm-navigation-dropdown__option"><button class="tm-navigation-dropdown__option-button">
#         по релевантности
#         <!-- --></button></li><li class="tm-navigation-dropdown__option"><button class="tm-navigation-dropdown__option-button">
#         по времени
#         <!-- --></button></li><li class="tm-navigation-dropdown__option"><button class="tm-navigation-dropdown__option-button">
#         по рейтингу
#         <!-- --></button></li></ul></div></div> <div class="tm-sub-page" data-async-called="true"><div class="tm-sub-page__main"><div><div class="tm-articles-list"><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="490834" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/ITSumma/" title="ITSumma"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/b2e/6ed/663/b2e6ed663804346daf634c66b987fe62.png" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/ITSumma/">
#       ITSumma
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2020-03-03T10:22:32.000Z" title="2020-03-03, 13:22">3  мар  2020 в 13:22</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/companies/itsumma/news/490834/"><span>В начале этого года <em class="searched-item">Python</em> сместил Java и стал вторым по популярности языком программирования среди разработчиков</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     2 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">27K</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 31: ↑31 и ↓0</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 31: ↑31 и ↓0">+31</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     21
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/companies/itsumma/news/490834/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       35
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="728568" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/sepulkary/" title="sepulkary"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/a29/1c3/e8a/a291c3e8a64e4969a58c4c537f44bb8f.png" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/sepulkary/">
#       sepulkary
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2023-04-12T09:57:56.000Z" title="2023-04-12, 12:57">12  апр   в 12:57</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/articles/728568/"><span>Ядро планеты <em class="searched-item">Python</em>. Интерактивный учебник</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     67 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">20K</span></span></div> <!-- --> <div class="tm-article-snippet__labels-container"><div class="tm-article-snippet__labels"><div class="tm-article-snippet__label tm-article-snippet__label_variant-tutorial"><span>
#           Туториал
#         </span></div> </div></div> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 66: ↑66 и ↓0</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 66: ↑66 и ↓0">+66</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     362
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/articles/728568/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       25
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="745680" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/UprightMan/" title="UprightMan"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/a2e/041/94e/a2e04194e4996406fb2493d8f2c94a2a.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/UprightMan/">
#       UprightMan
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2023-07-10T08:00:02.000Z" title="2023-07-10, 11:00">10  июл   в 11:00</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/companies/first/articles/745680/"><span>Опенсорс-библиотеки для <em class="searched-item">Python</em>: 40+ вариантов, как упростить жизнь начинающего дата-сайентиста</span></a></h2> <div class="tm-article-snippet__stats"><div class="tm-article-complexity tm-article-complexity_complexity-low"><span class="tm-svg-icon__wrapper tm-article-complexity__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Уровень сложности</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#complexity-low"></use></svg></span> <span class="tm-article-complexity__label">
#     Простой
#   </span></div> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     22 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">3.8K</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 11: ↑11 и ↓0</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 11: ↑11 и ↓0">+11</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     113
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/companies/first/articles/745680/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       0
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="683536" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/Jessy_James/" title="Jessy_James"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="https://assets.habr.com/habr-web/img/avatars/118.png" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/Jessy_James/">
#       Jessy_James
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2022-09-26T10:54:02.000Z" title="2022-09-26, 13:54">26  сен  2022 в 13:54</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/articles/683536/"><span>Java из <em class="searched-item">Python</em> (Kivy) и обратно на Android</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     6 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">6K</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 4: ↑4 и ↓0</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 4: ↑4 и ↓0">+4</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     44
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/articles/683536/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       0
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="746622" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/SovaSova15/" title="SovaSova15"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/f31/9aa/add/f319aaadd5efb8d5489929edc802f6f4.png" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/SovaSova15/">
#       SovaSova15
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2023-07-07T12:27:16.000Z" title="2023-07-07, 15:27">7  июл   в 15:27</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/companies/southbridge/articles/746622/"><span>Как сделать из <em class="searched-item">Python</em>-скрипта исполняемый файл</span></a></h2> <div class="tm-article-snippet__stats"><div class="tm-article-complexity tm-article-complexity_complexity-low"><span class="tm-svg-icon__wrapper tm-article-complexity__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Уровень сложности</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#complexity-low"></use></svg></span> <span class="tm-article-complexity__label">
#     Простой
#   </span></div> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     3 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">14K</span></span></div> <!-- --> <div class="tm-article-snippet__labels-container"><div class="tm-article-snippet__labels"><div class="tm-article-snippet__label tm-article-snippet__label_variant-tutorial"><span>
#           Туториал
#         </span></div> <div class="tm-article-snippet__label tm-article-snippet__label tm-article-snippet__label_variant-translation"><span>
#           Перевод
#         </span></div></div></div> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 28: ↑18 и ↓10</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 28: ↑18 и ↓10">+8</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     161
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/companies/southbridge/articles/746622/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       27
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="473926" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/maybe_elf/" title="maybe_elf"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/592/11d/4bc/59211d4bcd7f9afdadaef515b2b0706d.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/maybe_elf/">
#       maybe_elf
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2019-10-31T07:02:54.000Z" title="2019-10-31, 10:02">31  окт  2019 в 10:02</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/news/473926/"><span>Создатель <em class="searched-item">Python</em> Гвидо ван Россум ушел из Dropbox на пенсию</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     2 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">13K</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 25: ↑24 и ↓1</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 25: ↑24 и ↓1">+23</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     11
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/news/473926/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       21
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="746686" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/nikotin55/" title="nikotin55"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/b48/18a/753/b4818a7532db45ac29fd3a1798de62aa.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/nikotin55/">
#       nikotin55
#       <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2023-07-07T19:50:27.000Z" title="2023-07-07, 22:50">7  июл   в 22:50</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/articles/746686/"><span>Линейная алгебра самым простым языком с добавлением фишек из <em class="searched-item">Python</em> (часть 1)</span></a></h2> <div class="tm-article-snippet__stats"><div class="tm-article-complexity tm-article-complexity_complexity-low"><span class="tm-svg-icon__wrapper tm-article-complexity__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Уровень сложности</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#complexity-low"></use></svg></span> <span class="tm-article-complexity__label">
#     Простой
#   </span></div> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#     3 мин
#   </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">6.6K</span></span></div> <!-- --> <div class="tm-article-snippet__labels-container"><div class="tm-article-snippet__labels"><!-- --> <div class="tm-article-snippet__label tm-article-snippet__label tm-article-snippet__label_variant-sandbox"><a href="/ru/sandbox/">
#           Из песочницы
#         </a></div></div></div> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 19: ↑11 и ↓8</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 19: ↑11 и ↓8">+3</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     67
#   </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/articles/746686/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#       9
#     </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article> <!-- --><!-- --> <article class="tm-articles-list__item" data-navigatable="" id="723806" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/yadro_team/" title="yadro_team"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/643/716/787/643716787bd18f3c4b710d7530a12579.png" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/yadro_team/">
#       yadro_team
# ...
#         0
#       </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article>,
#   <article class="tm-articles-list__item" data-navigatable="" id="724246" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/Evrone/" title="Evrone"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/933/206/980/93320698056343d9dea3128fad3589a4.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/Evrone/">
#         Evrone
#         <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2023-03-23T08:52:58.000Z" title="2023-03-23, 11:52">23  мар   в 11:52</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/companies/evrone/news/724246/"><span>Углубляемся в <em class="searched-item">Python</em> на Evrone meetup</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#       1 мин
#     </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">319</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 3: ↑2 и ↓1</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 3: ↑2 и ↓1">+1</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#       1
#     </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/companies/evrone/news/724246/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#         0
#       </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article>,
#   <article class="tm-articles-list__item" data-navigatable="" id="646825" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/Hedgehog_art/" title="Hedgehog_art"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/d5b/8fa/51c/d5b8fa51cf1f35bcfae21586e8fd771d.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/Hedgehog_art/">
#         Hedgehog_art
#         <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2022-01-20T15:37:16.000Z" title="2022-01-20, 18:37">20  янв  2022 в 18:37</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/companies/southbridge/news/646825/"><span>Курс «<em class="searched-item">Python</em> для инженеров». Старт 3 потока 31 января</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#       7 мин
#     </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">8.7K</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 14: ↑12 и ↓2</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 14: ↑12 и ↓2">+10</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#       17
#     </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/companies/southbridge/news/646825/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#         1
#       </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article>,
#   <article class="tm-articles-list__item" data-navigatable="" id="498364" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/denis-19/" title="denis-19"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/6a0/f31/235/6a0f31235bb26134f3c7a741c03e4efb.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/denis-19/">
#         denis-19
#         <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2020-04-21T15:35:14.000Z" title="2020-04-21, 18:35">21  апр  2020 в 18:35</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/news/498364/"><span>Вышел <em class="searched-item">Python</em> 2.7.18, последний релиз ветки <em class="searched-item">Python</em> 2.x</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#       1 мин
#     </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">9.5K</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 19: ↑19 и ↓0</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 19: ↑19 и ↓0">+19</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#       6
#     </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/news/498364/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#         7
#       </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article>,
#   <article class="tm-articles-list__item" data-navigatable="" id="595093" tabindex="0"><div class="tm-article-snippet tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/geniyoctober/" title="geniyoctober"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/53f/de7/020/53fde7020b74de978d3c1d2fb2d1febc.jpg" width="32"/></div></a> <span class="tm-user-info__user tm-user-info__user_appearance-default"><a class="tm-user-info__username" href="/ru/users/geniyoctober/">
#         geniyoctober
#         <!-- --></a> <span class="tm-article-datetime-published"><time datetime="2021-12-13T06:00:03.000Z" title="2021-12-13, 09:00">13  дек  2021 в 09:00</time></span></span></span></div> <!-- --></div> <h2 class="tm-title tm-title_h2"><a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/companies/southbridge/news/595093/"><span>Жаждущим автоматизации: открытый урок «ChatOps c Errbot на <em class="searched-item">Python</em>», 21 декабря</span></a></h2> <div class="tm-article-snippet__stats"><!-- --> <div class="tm-article-reading-time"><span class="tm-svg-icon__wrapper tm-article-reading-time__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Время на прочтение</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock"></use></svg></span> <span class="tm-article-reading-time__label">
#       7 мин
#     </span></div> <span class="tm-icon-counter tm-data-icons__item"><svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24"><title>Количество просмотров</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views"></use></svg> <span class="tm-icon-counter__value">2.7K</span></span></div> <!-- --> <!-- --> <!-- --> <!-- --></div> <div class="tm-data-icons"><!-- --> <div class="tm-votes-meter tm-data-icons__item"><svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24"><title>Всего голосов 11: ↑10 и ↓1</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating"></use></svg> <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 11: ↑10 и ↓1">+9</span></div> <!-- --> <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button"><span class="tm-svg-icon__wrapper bookmarks-button__icon"><svg class="tm-svg-img tm-svg-icon" height="24" width="24"><title>Добавить в закладки</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite"></use></svg></span> <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#       7
#     </span></button> <div class="tm-sharing tm-data-icons__item" title="Поделиться"><button class="tm-sharing__button" type="button"><svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor"></path></svg></button> <div class="v-portal" style="display:none;"></div></div> <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии"><a class="tm-article-comments-counter-link__link" href="/ru/companies/southbridge/news/595093/comments/"><svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24"><title>Комментарии</title> <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments"></use></svg> <span class="tm-article-comments-counter-link__value">
#         0
#       </span></a> <!-- --></div> <div class="v-portal" style="display:none;"></div></div></article>])

# %%
print(type(searched))
print(searched[4].prettify())
# Out:
# <class 'bs4.element.ResultSet'>
# <article class="tm-articles-list__item" data-navigatable="" id="473926" tabindex="0">
#  <div class="tm-article-snippet tm-article-snippet">
#   <div class="tm-article-snippet__meta-container">
#    <div class="tm-article-snippet__meta">
#     <span class="tm-user-info tm-article-snippet__author">
#      <a class="tm-user-info__userpic" href="/ru/users/maybe_elf/" title="maybe_elf">
#       <div class="tm-entity-image">
#        <img alt="" class="tm-entity-image__pic" height="32" src="//habrastorage.org/r/w64/getpro/habr/avatars/592/11d/4bc/59211d4bcd7f9afdadaef515b2b0706d.jpg" width="32"/>
#       </div>
#      </a>
#      <span class="tm-user-info__user tm-user-info__user_appearance-default">
#       <a class="tm-user-info__username" href="/ru/users/maybe_elf/">
#        maybe_elf
#        <!-- -->
#       </a>
#       <span class="tm-article-datetime-published">
#        <time datetime="2019-10-31T07:02:54.000Z" title="2019-10-31, 10:02">
#         31  окт  2019 в 10:02
#        </time>
#       </span>
#      </span>
#     </span>
#    </div>
#    <!-- -->
#   </div>
#   <h2 class="tm-title tm-title_h2">
#    <a class="tm-title__link" data-article-link="true" data-test-id="article-snippet-title-link" href="/ru/news/473926/">
#     <span>
#      Создатель
#      <em class="searched-item">
#       Python
#      </em>
#      Гвидо ван Россум ушел из Dropbox на пенсию
#     </span>
#    </a>
#   </h2>
#   <div class="tm-article-snippet__stats">
#    <!-- -->
#    <div class="tm-article-reading-time">
#     <span class="tm-svg-icon__wrapper tm-article-reading-time__icon">
#      <svg class="tm-svg-img tm-svg-icon" height="24" width="24">
#       <title>
#        Время на прочтение
#       </title>
#       <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#clock">
#       </use>
#      </svg>
#     </span>
#     <span class="tm-article-reading-time__label">
#      2 мин
#     </span>
#    </div>
#    <span class="tm-icon-counter tm-data-icons__item">
#     <svg class="tm-svg-img tm-icon-counter__icon" height="24" width="24">
#      <title>
#       Количество просмотров
#      </title>
#      <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-views">
#      </use>
#     </svg>
#     <span class="tm-icon-counter__value">
#      13K
#     </span>
#    </span>
#   </div>
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#  </div>
#  <div class="tm-data-icons">
#   <!-- -->
#   <div class="tm-votes-meter tm-data-icons__item">
#    <svg class="tm-svg-img tm-votes-meter__icon tm-votes-meter__icon tm-votes-meter__icon_appearance-article" height="24" width="24">
#     <title>
#      Всего голосов 25: ↑24 и ↓1
#     </title>
#     <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-rating">
#     </use>
#    </svg>
#    <span class="tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating" title="Всего голосов 25: ↑24 и ↓1">
#     +23
#    </span>
#   </div>
#   <!-- -->
#   <button class="bookmarks-button tm-data-icons__item" title="Добавить в закладки" type="button">
#    <span class="tm-svg-icon__wrapper bookmarks-button__icon">
#     <svg class="tm-svg-img tm-svg-icon" height="24" width="24">
#      <title>
#       Добавить в закладки
#      </title>
#      <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-favorite">
#      </use>
#     </svg>
#    </span>
#    <span class="bookmarks-button__counter" title="Количество пользователей, добавивших публикацию в закладки">
#     11
#    </span>
#   </button>
#   <div class="tm-sharing tm-data-icons__item" title="Поделиться">
#    <button class="tm-sharing__button" type="button">
#     <svg class="tm-sharing__icon" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#      <path d="M13.8 13.8V18l7.2-6.6L13.8 5v3.9C5 8.9 3 18.6 3 18.6c2.5-4.4 6-4.8 10.8-4.8z" fill="currentColor">
#      </path>
#     </svg>
#    </button>
#    <div class="v-portal" style="display:none;">
#    </div>
#   </div>
#   <div class="tm-article-comments-counter-link tm-data-icons__item" title="Читать комментарии">
#    <a class="tm-article-comments-counter-link__link" href="/ru/news/473926/comments/">
#     <svg class="tm-svg-img tm-article-comments-counter-link__icon" height="24" width="24">
#      <title>
#       Комментарии
#      </title>
#      <use xlink:href="/img/megazord-v28.2fb1b1c1..svg#counter-comments">
#      </use>
#     </svg>
#     <span class="tm-article-comments-counter-link__value">
#      21
#     </span>
#    </a>
#    <!-- -->
#   </div>
#   <div class="v-portal" style="display:none;">
#   </div>
#  </div>
# </article>

# %%
print(searched[4].find('h2', 'tm-title tm-title_h2').text)
# print(searched[0].find('div', 'tm-votes-meter tm-data-icons__item').text)
print(searched[4].find('span', 
                       'tm-votes-meter__value tm-votes-meter__value tm-votes-meter__value_positive tm-votes-meter__value_appearance-article tm-votes-meter__value_rating').text)
# Out:
# Создатель Python Гвидо ван Россум ушел из Dropbox на пенсию
# +23

# %%
el = searched[0]
title = el.find('h2', 'tm-title tm-title_h2').text
date = el.find('span', 'tm-article-datetime-published').text

# ссылки в href локальные, надо добавлять домен вручную
link = el.find('a', 'tm-title__link').get('href')
link_full = requests.compat.urljoin(URL_domain, link)

print(title, date, link_full)
# Out:
# Ядро планеты Python. Интерактивный учебник 12  апр   в 12:57 https://habr.com/ru/articles/728568/

# %%
URL = 'https://habr.com/ru/news/473926/'

res = requests.get(URL)
soup = BeautifulSoup(res.text)
art_txt = soup.find('div', id = 'post-content-body').text.strip()

# %%
art_txt = soup.find('div', id = 'post-content-body').text.strip()
art_txt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[198], line 2
#       1 art_txt = soup.find('div', id = 'post-content-body').text.strip()
# ----> 2 art_txt.prettify()
#
# AttributeError: 'str' object has no attribute 'prettify'

# %%
s = '2'
print(type(s))
si = int(s)
print(type(si))
# Out:
# <class 'str'>
# <class 'int'>

# %%
st = 'afac'
# %echo st.replace('a', 'b')
# Out:
# st.replace('a', 'b')

# %%
print(f'{123.444:.2f}')
# Out:
# 123.44

# %%
my_example = {'some_item': 2, 'other_item': 20}
type(my_example)
# Out:
# dict
